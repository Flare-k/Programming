# %%
import pandas as pd

# %%
train = pd.read_csv('FIFA_train.csv')

# %%
train.head(50)
# Out:
#     id                 name  age      continent contract_until position  \
# 0    0             L. Messi   31  south america           2021       ST
# 1    3               De Gea   27         europe           2020       GK
# 2    7            L. Suárez   31  south america           2021       ST
# 3    8         Sergio Ramos   32         europe           2020       DF
# 4    9             J. Oblak   25         europe           2021       GK
# 5   12             D. Godín   32  south america           2019       DF
# 6   13          David Silva   32         europe           2020       MF
# 7   14             N. Kanté   27         europe           2023       MF
# 8   18        M. ter Stegen   26         europe           2022       GK
# 9   19          T. Courtois   26         europe           2024       GK
# 10  20      Sergio Busquets   29         europe           2023       MF
# 11  21            E. Cavani   31  south america           2020       ST
# 12  22             M. Neuer   32         europe           2021       GK
# 13  24         G. Chiellini   33         europe           2020       DF
# 14  26             M. Salah   26         africa           2023       MF
# 15  27             Casemiro   26  south america           2021       MF
# 16  29           L. Insigne   27         europe           2022       ST
# 17  30                 Isco   26         europe           2022       ST
# 18  32             Coutinho   26  south america           2023       ST
# 19  33        P. Aubameyang   29         africa           2021       MF
# 20  34           M. Hummels   29         europe           2021       DF
# 21  37            H. Lloris   31         europe           2022       GK
# 22  38           G. Higuaín   30  south america   Jun 30, 2019       ST
# 23  41            G. Buffon   40         europe           2019       GK
# 24  42            S. Umtiti   24         europe           2023       DF
# 25  44         K. Koulibaly   27         africa           2021       DF
# 26  45             P. Pogba   25         europe           2021       MF
# 27  47            R. Lukaku   25         europe           2022       ST
# 28  49           Jordi Alba   29         europe           2020       DF
# 29  50           D. Mertens   31         europe           2020       ST
# 30  52            M. Hamšík   30         europe           2020       MF
# 31  53           I. Rakitić   30         europe           2021       MF
# 32  54                Piqué   31         europe           2022       DF
# 33  58              S. Mané   26         africa           2023       MF
# 34  59          V. van Dijk   26         europe           2023       DF
# 35  63          M. Verratti   25         europe           2021       MF
# 36  64          Alex Sandro   27  south america           2020       DF
# 37  65        Douglas Costa   27  south america           2022       MF
# 38  66            T. Müller   28         europe           2021       MF
# 39  67               Thiago   27         europe           2021       MF
# 40  68              M. Reus   29         europe           2023       MF
# 41  73           M. Benatia   31         africa           2020       DF
# 42  75          Fernandinho   33  south america           2020       MF
# 43  76              Iniesta   34         europe           2021       ST
# 44  77          M. Škriniar   23         europe           2022       DF
# 45  78  S. Milinković-Savić   23         europe           2023       MF
# 46  79        Marco Asensio   22         europe           2023       ST
# 47  81              Alisson   25  south america           2024       GK
# 48  83                 Saúl   23         europe           2026       MF
# 49  86                 Koke   26         europe           2019       MF
#
#    prefer_foot  reputation  stat_overall  stat_potential  stat_skill_moves  \
# 0         left         5.0            94              94               4.0
# 1        right         4.0            91              93               1.0
# 2        right         5.0            91              91               3.0
# 3        right         4.0            91              91               3.0
# 4        right         3.0            90              93               1.0
# 5        right         3.0            90              90               2.0
# 6         left         4.0            90              90               4.0
# 7        right         3.0            89              90               2.0
# 47   36500000.0          3.400000
# 48   50500000.0          3.695652
# 49   45000000.0          3.269231

# %% [markdown]
# ### stat_overall이 높아도 나이가 많으면 좋은게 아니다.

# %%
import matplotlib.pyplot as plt

# %%
train['age_stat_overall'] = train['stat_overall']/train['age']

# %%
train.head()
# Out:
#    id          name  age      continent contract_until position prefer_foot  \
# 0   0      L. Messi   31  south america           2021       ST        left
# 1   3        De Gea   27         europe           2020       GK       right
# 2   7     L. Suárez   31  south america           2021       ST       right
# 3   8  Sergio Ramos   32         europe           2020       DF       right
# 4   9      J. Oblak   25         europe           2021       GK       right
#
#    reputation  stat_overall  stat_potential  stat_skill_moves        value  \
# 0         5.0            94              94               4.0  110500000.0
# 1         4.0            91              93               1.0   72000000.0
# 2         5.0            91              91               3.0   80000000.0
# 3         4.0            91              91               3.0   51000000.0
# 4         3.0            90              93               1.0   68000000.0
#
#    age_stat_overall
# 0          3.032258
# 1          3.370370
# 2          2.935484
# 3          2.843750
# 4          3.600000

# %%
import seaborn as sns

# %%
sns.countplot(train['age_stat_overall'])
#'오버롤/나이'에 대한 시각화

# %%
train.groupby('age').mean().plot()

# %%
train.groupby('stat_overall').mean().plot()

# %%
train.groupby('age_stat_overall').mean().plot()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 100)

# %%
x = train[['age', 'continent', 'position', 'stat_overall', 'stat_potential', 'age_stat_overall']]

# %%
x.head(10)
# Out:
#    age      continent position  stat_overall  stat_potential  age_stat_overall
# 0   31  south america       ST            94              94          3.032258
# 1   27         europe       GK            91              93          3.370370
# 2   31  south america       ST            91              91          2.935484
# 3   32         europe       DF            91              91          2.843750
# 4   25         europe       GK            90              93          3.600000
# 5   32  south america       DF            90              90          2.812500
# 6   32         europe       MF            90              90          2.812500
# 7   27         europe       MF            89              90          3.296296
# 8   26         europe       GK            89              92          3.423077
# 9   26         europe       GK            89              90          3.423077

# %%
x['continent'].unique()
# Out:
# array(['south america', 'europe', 'africa', 'asia', 'oceania'],
#       dtype=object)

# %%
#문자를 숫자로 처리해주는 작업
x['continent'] = x['continent'].map({'south america':0, 'europe':1, 'africa':2, 'asia':3, 'oceania':4})
# Out:
# /Users/noblyan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
x.head(10)
# Out:
#    age  continent position  stat_overall  stat_potential  age_stat_overall
# 0   31          0       ST            94              94          3.032258
# 1   27          1       GK            91              93          3.370370
# 2   31          0       ST            91              91          2.935484
# 3   32          1       DF            91              91          2.843750
# 4   25          1       GK            90              93          3.600000
# 5   32          0       DF            90              90          2.812500
# 6   32          1       MF            90              90          2.812500
# 7   27          1       MF            89              90          3.296296
# 8   26          1       GK            89              92          3.423077
# 9   26          1       GK            89              90          3.423077

# %%
#포지션도 문자이므로 숫자로 처리해줄것.
x['position'].unique()
# Out:
# array(['ST', 'GK', 'DF', 'MF'], dtype=object)

# %%
x['position'] = x['position'].map({'ST':0, 'GK':1, 'DF':2, 'MF':3})
# Out:
# /Users/noblyan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x.head(10)
# Out:
#    age  continent  position  stat_overall  stat_potential  age_stat_overall
# 0   31          0         0            94              94          3.032258
# 1   27          1         1            91              93          3.370370
# 2   31          0         0            91              91          2.935484
# 3   32          1         2            91              91          2.843750
# 4   25          1         1            90              93          3.600000
# 5   32          0         2            90              90          2.812500
# 6   32          1         3            90              90          2.812500
# 7   27          1         3            89              90          3.296296
# 8   26          1         1            89              92          3.423077
# 9   26          1         1            89              90          3.423077

# %%
# 무엇을 예측할 것인지 입력
y = train['value']

# %%
rf.fit(x, y)   #x를 통해 y를 알아내겠다
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
test = pd.read_csv('FIFA_test.csv')

# %%
test.head()
# Out:
#    id               name  age      continent contract_until position  \
# 0   1  Cristiano Ronaldo   33         europe           2022       ST
# 1   2          Neymar Jr   26  south america           2022       ST
# 2   4       K. De Bruyne   27         europe           2023       MF
# 3   5          E. Hazard   27         europe           2020       ST
# 4   6          L. Modrić   32         europe           2020       MF
#
#   prefer_foot  reputation  stat_overall  stat_potential  stat_skill_moves
# 0       right         5.0            94              94               5.0
# 1       right         5.0            92              93               5.0
# 2       right         4.0            91              92               4.0
# 3       right         4.0            91              91               4.0
# 4       right         4.0            91              91               4.0

# %%
test['age_stat_overall'] = test['stat_overall']/test['age']

# %%
test.head(10)
# Out:
#    id               name  age      continent contract_until position  \
# 0   1  Cristiano Ronaldo   33         europe           2022       ST
# 1   2          Neymar Jr   26  south america           2022       ST
# 2   4       K. De Bruyne   27         europe           2023       MF
# 3   5          E. Hazard   27         europe           2020       ST
# 4   6          L. Modrić   32         europe           2020       MF
# 5  10     R. Lewandowski   29         europe           2021       ST
# 6  11           T. Kroos   28         europe           2022       MF
# 7  15          P. Dybala   24  south america           2022       ST
# 8  17       A. Griezmann   27         europe           2023       MF
# 9  23          S. Agüero   30  south america           2021       ST
#
#   prefer_foot  reputation  stat_overall  stat_potential  stat_skill_moves  \
# 0       right         5.0            94              94               5.0
# 1       right         5.0            92              93               5.0
# 2       right         4.0            91              92               4.0
# 3       right         4.0            91              91               4.0
# 4       right         4.0            91              91               4.0
# 5       right         4.0            90              90               4.0
# 6       right         4.0            90              90               3.0
# 7        left         3.0            89              94               4.0
# 8        left         4.0            89              90               4.0
# 9       right         4.0            89              89               4.0
#
#    age_stat_overall
# 0          2.848485
# 1          3.538462
# 2          3.370370
# 3          3.370370
# 4          2.843750
# 5          3.103448
# 6          3.214286
# 7          3.708333
# 8          3.296296
# 9          2.966667

# %%
x2 = test[['age', 'continent', 'position', 'stat_overall', 'stat_potential', 'age_stat_overall']]

# %%
x2.head(10)
# Out:
#    age      continent position  stat_overall  stat_potential  age_stat_overall
# 0   33         europe       ST            94              94          2.848485
# 1   26  south america       ST            92              93          3.538462
# 2   27         europe       MF            91              92          3.370370
# 3   27         europe       ST            91              91          3.370370
# 4   32         europe       MF            91              91          2.843750
# 5   29         europe       ST            90              90          3.103448
# 6   28         europe       MF            90              90          3.214286
# 7   24  south america       ST            89              94          3.708333
# 8   27         europe       MF            89              90          3.296296
# 9   30  south america       ST            89              89          2.966667

# %%
x2['continent'].unique()
# Out:
# array(['europe', 'south america', 'africa', 'asia', 'oceania'],
#       dtype=object)

# %%
x2['continent'] = x2['continent'].map({'south america':0, 'europe':1, 'africa':2, 'asia':3, 'oceania':4})
# Out:
# /Users/noblyan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x2.head(10)
# Out:
#    age  continent position  stat_overall  stat_potential  age_stat_overall
# 0   33          1       ST            94              94          2.848485
# 1   26          0       ST            92              93          3.538462
# 2   27          1       MF            91              92          3.370370
# 3   27          1       ST            91              91          3.370370
# 4   32          1       MF            91              91          2.843750
# 5   29          1       ST            90              90          3.103448
# 6   28          1       MF            90              90          3.214286
# 7   24          0       ST            89              94          3.708333
# 8   27          1       MF            89              90          3.296296
# 9   30          0       ST            89              89          2.966667

# %%
x2['position'].unique()
# Out:
# array(['ST', 'MF', 'DF', 'GK'], dtype=object)

# %%
x2['position'] = x2['position'].map({'ST':0, 'GK':1, 'DF':2, 'MF':3})
# Out:
# /Users/noblyan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x2.head(10)
# Out:
#    age  continent  position  stat_overall  stat_potential  age_stat_overall
# 0   33          1         0            94              94          2.848485
# 1   26          0         0            92              93          3.538462
# 2   27          1         3            91              92          3.370370
# 3   27          1         0            91              91          3.370370
# 4   32          1         3            91              91          2.843750
# 5   29          1         0            90              90          3.103448
# 6   28          1         3            90              90          3.214286
# 7   24          0         0            89              94          3.708333
# 8   27          1         3            89              90          3.296296
# 9   30          0         0            89              89          2.966667

# %%
answer = test['id']   #동명이인 경우 고려하여 id값을 넣음

# %%
answer = pd.DataFrame(answer)
answer
# Out:
#          id
# 0         1
# 1         2
# 2         4
# 3         5
# 4         6
# 5        10
# 6        11
# 7        15
# 8        17
# 9        23
# 10       25
# 11       28
# 12       31
# 13       35
# 14       39
# 15       40
# 16       43
# 17       48
# 18       51
# 19       55
# 20       56
# 21       57
# 22       61
# 23       62
# 24       69
# 25       70
# 26       71
# 27       74
# 28       80
# 29       82
# ...     ...
# 3798  16702
# 3799  16705
# 3800  16707
# 3801  16721
# 3802  16722
# 3803  16728
# 3804  16733
# 3805  16746
# 3806  16762
# 3807  16773
# 3808  16778
# 3809  16784
# 3810  16801
# 3811  16814
# 3812  16818
# 3813  16838
# 3814  16854
# 3815  16861
# 3816  16872
# 3817  16873
# 3818  16874
# 3819  16888
# 3820  16889
# 3821  16913
# 3822  16918
# 3823  16924
# 3824  16929
# 3825  16932
# 3826  16937
# 3827  16943
#
# [3828 rows x 1 columns]

# %%
answer['value'] = rf.predict(x2)
# 컴퓨터가 학습한 것을 토대로 예측을 완료

# %%
answer.head()    # age_stat_overall 기준으로 value로 순위가 매겨짐
# Out:
#    id        value
# 0   1  110500000.0
# 1   2   58000000.0
# 2   4   63000000.0
# 3   5   73500000.0
# 4   6   60000000.0

# %%
answer.to_csv('answer.csv', index = False)
